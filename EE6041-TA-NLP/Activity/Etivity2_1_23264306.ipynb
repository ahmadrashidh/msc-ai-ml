# %% [markdown]
# # Etivity 2.1

# %% [markdown]
# Student Name: Ahmad Rashidh
#
# Student ID: 23264306

# %% [markdown]
# ### Task 1

# %%
import time

# %%
cost_ins = 1
cost_del = 1
cost_sub_ltr = 1
cost_sub_no = 2
#How many insertions, deletions, or substitutions does it take to turn x into y?
def edDistRecursive(x, y):

    # If either x or y are empty, then one or more (depending on their length) INSERTIONS or DELECTIONS are needed to transform x to y.
    if len(x) == 0:
        #print(f'\t Converting "{x}" TO "{y}" requires {len(y)} INSERTIONS, therefor it costs {len(y)}')
        return len(y)
    if len(y) == 0:
        #print(f'\t Converting "{x}" TO "{y}" requires {len(x)} DELETIONS, therefor it costs {len(x)}')
        return len(x)

    # When neither x or y are empty, we must compute the cost of each operation and find the least costly one.
    delta = 1 if x[-1] != y[-1] else 0

    if x[-1].isalpha() and y[-1].isnumeric() and delta==1:
        delta=2

    diagonal_or_substitution_cost = edDistRecursive(x[:-1], y[:-1]) + delta #what's the cost of SUBSTITUTING the last character of x with the last character of y
    vertical_or_deletion_cost     = edDistRecursive(x[:-1], y)      + cost_del    #what's the cost of DELETING the last character of x
    horizontal_or_insertion_cost  = edDistRecursive(x, y[:-1])      + cost_ins     #what's the cost of INSERTING the last character of x into y

    # what's the least costly operation?
    minValue = min(diagonal_or_substitution_cost, vertical_or_deletion_cost, horizontal_or_insertion_cost)
    return minValue

# %%
secs = time.time()
print('Edit Distance between "intention" and "execution" is', edDistRecursive("intention","execution"))
print(f'-----Executed in: {secs} seconds-------')
# Out:
# Edit Distance between "intention" and "execution" is 5
# -----Executed in: 1696599926.6158855 seconds-------

# %% [markdown]
# ### Task 2

# %%
# !pip install names-dataset
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 MB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 88.7 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for names-dataset: filename=names_dataset-3.1.0-py3-none-any.whl size=116832759 sha256=dc39c9036be4b7ebaddfd9b5d585c12670ef1013b87c9f61a4b0b2cb7040be69
#   Stored in directory: /root/.cache/pip/wheels/cf/f8/43/0c4aba87b34e971e7255a41f11dc0035c5e55b026dc3480986
# ...
#   Created wheel for pycountry: filename=pycountry-22.3.5-py2.py3-none-any.whl size=10681833 sha256=afb556823c60c351e165abf958bf9a3e019efc36361a867876ce1d8addc30e1f
#   Stored in directory: /root/.cache/pip/wheels/03/57/cc/290c5252ec97a6d78d36479a3c5e5ecc76318afcb241ad9dbe
# Successfully built names-dataset pycountry
# ...

# %%
# !pip install jellyfish
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 13.1 MB/s eta 0:00:00
# ...

# %%
from names_dataset import NameDataset, NameWrapper
import jellyfish
nd = NameDataset()

# %% [markdown]
# ### A

# %%
def nd_exists(fn, ln):
  return nd.search(fn)["first_name"] != None, nd.search(ln)["last_name"] != None

# %%
nd_exists("Walter","Vetrivel")
# Out:
# (True, True)

# %% [markdown]
# ### B

# %%
def print_soundexcodes(fn,ln):
  fn_soundex = jellyfish.soundex(fn)
  ln_soundex = jellyfish.soundex(ln)
  print(f"Soundex of Firstname: {fn_soundex} | Soundex of Lastname: {ln_soundex}")

# %%
print_soundexcodes("Walter","Zoe")
# Out:
# Soundex of Firstname: W436 | Soundex of Lastname: Z000

# %% [markdown]
# ### C

# %%
def list_names_samesoundex(fn):
  fns_same_soundex = []
  fn_soundex=  jellyfish.soundex(fn)
  for name in nd.first_names:
    if fn_soundex ==  jellyfish.soundex(name):
      fns_same_soundex.append(name)
  print("List of first names in the dataset with same soundex: ", fns_same_soundex)

# %%
list_names_samesoundex("Walter")
# Out:
# List of first names in the dataset with same soundex:  ['Waalter', 'Wal Drin', 'Waldar', 'Waldeir', 'Walder', 'Walderich', 'Waldir', 'Waldirene', 'Waldrmar', 'Waldtraud', 'Waldtraut', 'Waldyr', 'Wallter', 'Waltar', 'Walteer', 'Walter', 'Walter A', 'Walter Abel', 'Walter Adolfo', 'Walter Adonis', 'Walter Adrian', 'Walter Agustin', 'Walter Alberto', 'Walter Alejandro', 'Walter Alex', 'Walter Alexander', 'Walter Alexis', 'Walter Alfredo', 'Walter Amilcar', 'Walter Andres', 'Walter Aneudy', 'Walter Angel', 'Walter Anibal', 'Walter Antonio', 'Walter António', 'Walter Ariel', 'Walter Armando', 'Walter Arnoldo', 'Walter Arturo', 'Walter Augusto', 'Walter Bathex', 'Walter Carlos', 'Walter Cesar', 'Walter Correia', 'Walter Costa', 'Walter Cutkhina', 'Walter D', 'Walter Da Silva', 'Walter Damian', 'Walter Danger', 'Walter Daniel', 'Walter Danilo', 'Walter Dario', 'Walter David', 'Walter De', 'Walter De Jesus', 'Walter Do', 'Walter Edgar', 'Walter Edgardo', 'Walter Eduardo', 'Walter Efrain', 'W
# ...

# %% [markdown]
# ### D

# %%
def levenshtein_dist(fn,ln):
  return jellyfish.levenshtein_distance(fn, ln)

# %%
levenshtein_dist("Walter","Vetrivel")
# Out:
# 7
